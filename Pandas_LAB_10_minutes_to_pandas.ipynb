# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.661299  1.781027  1.197734  0.881024
# 2013-01-03 -1.053949 -0.100556 -1.078170 -0.710167
# 2013-01-04  1.027068  0.934545  0.210337 -0.477388

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01  0.702666 -1.941495
# 2013-01-02 -1.661299  1.781027
# 2013-01-03 -1.053949 -0.100556
# 2013-01-04  1.027068  0.934545
# 2013-01-05 -1.283189  1.489698
# 2013-01-06  0.690789  0.379419

# %%
df.loc["20130102":"20130104", ["A", "B"]]
# Out:
#                    A         B
# 2013-01-02 -1.661299  1.781027
# 2013-01-03 -1.053949 -0.100556
# 2013-01-04  1.027068  0.934545

# %%
df.loc[dates[0], "A"]
# Out:
# 0.7026664077182628

# %%
df.at[dates[0], "A"]
# Out:
# 0.7026664077182628

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04  1.027068  0.934545
# 2013-01-05 -1.283189  1.489698

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -1.661299  1.197734
# 2013-01-03 -1.053949 -1.078170
# 2013-01-05 -1.283189  0.378899

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -1.661299  1.781027  1.197734  0.881024
# 2013-01-03 -1.053949 -0.100556 -1.078170 -0.710167

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01 -1.941495  0.836864
# 2013-01-02  1.781027  1.197734
# 2013-01-03 -0.100556 -1.078170
# 2013-01-04  0.934545  0.210337
# 2013-01-05  1.489698  0.378899
# 2013-01-06  0.379419 -1.186153

# %%
df.iloc[1, 1]
# Out:
# 1.7810266247296103

# %%
df.iat[1, 1]
# Out:
# 1.7810266247296103

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.702666 -1.941495  0.836864  1.567448
# 2013-01-04  1.027068  0.934545  0.210337 -0.477388
# 2013-01-06  0.690789  0.379419 -1.186153 -0.082415

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.702666       NaN  0.836864  1.567448
# 2013-01-02       NaN  1.781027  1.197734  0.881024
# 2013-01-03       NaN       NaN       NaN       NaN
# 2013-01-04  1.027068  0.934545  0.210337       NaN
# 2013-01-05       NaN  1.489698  0.378899       NaN
# 2013-01-06  0.690789  0.379419       NaN       NaN

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.702666 -1.941495  0.836864  1.567448    one
# 2013-01-02 -1.661299  1.781027  1.197734  0.881024    one
# 2013-01-03 -1.053949 -0.100556 -1.078170 -0.710167    two
# 2013-01-04  1.027068  0.934545  0.210337 -0.477388  three
# 2013-01-05 -1.283189  1.489698  0.378899 -0.057829   four
# 2013-01-06  0.690789  0.379419 -1.186153 -0.082415  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -1.053949 -0.100556 -1.078170 -0.710167   two
# 2013-01-05 -1.283189  1.489698  0.378899 -0.057829  four

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"] = s1
df.at[dates[0], "A"] = 0
df.iat[0, 1] = 0
df.loc[:, "D"] = np.array([5] * len(df))
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  0.836864  5.0  NaN
# 2013-01-02 -1.661299  1.781027  1.197734  5.0  1.0
# 2013-01-03 -1.053949 -0.100556 -1.078170  5.0  2.0
# 2013-01-04  1.027068  0.934545  0.210337  5.0  3.0
# 2013-01-05 -1.283189  1.489698  0.378899  5.0  4.0
# 2013-01-06  0.690789  0.379419 -1.186153  5.0  5.0

# %%
df2 = df.copy()
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -0.836864 -5.0  NaN
# 2013-01-02 -1.661299 -1.781027 -1.197734 -5.0 -1.0
# 2013-01-03 -1.053949 -0.100556 -1.078170 -5.0 -2.0
# 2013-01-04 -1.027068 -0.934545 -0.210337 -5.0 -3.0
# 2013-01-05 -1.283189 -1.489698 -0.378899 -5.0 -4.0
# 2013-01-06 -0.690789 -0.379419 -1.186153 -5.0 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])
df1.loc[dates[0] : dates[1], "E"] = 1
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.836864  5.0  NaN  1.0
# 2013-01-02 -1.661299  1.781027  1.197734  5.0  1.0  1.0
# 2013-01-03 -1.053949 -0.100556 -1.078170  5.0  2.0  NaN
# 2013-01-04  1.027068  0.934545  0.210337  5.0  3.0  NaN

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -1.661299  1.781027  1.197734  5.0  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  0.836864  5.0  5.0  1.0
# 2013-01-02 -1.661299  1.781027  1.197734  5.0  1.0  1.0
# 2013-01-03 -1.053949 -0.100556 -1.078170  5.0  2.0  5.0
# 2013-01-04  1.027068  0.934545  0.210337  5.0  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A   -0.380097
# B    0.747355
# C    0.059918
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.459216
# 2013-01-02    1.463492
# 2013-01-03    0.953465
# 2013-01-04    2.034390
# 2013-01-05    1.917082
# 2013-01-06    1.976811
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -2.053949 -1.100556 -2.078170  4.0  1.0
# 2013-01-04 -1.972932 -2.065455 -2.789663  2.0  0.0
# 2013-01-05 -6.283189 -3.510302 -4.621101  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -2.128541
# B     4.185191
# C     0.335543
# D    28.000000
# F    16.800000
# dtype: float64

# %%
df.transform(lambda x: x * 101.2)
# Out:
#                      A           B           C      D      F
# 2013-01-01    0.000000    0.000000   84.690608  506.0    NaN
# 2013-01-02 -168.123455  180.239894  121.210649  506.0  101.2
# 2013-01-03 -106.659674  -10.176232 -109.110842  506.0  202.4
# 2013-01-04  103.939325   94.575964   21.286154  506.0  303.6
# 2013-01-05 -129.858677  150.757444   38.344559  506.0  404.8
# 2013-01-06   69.907810   38.397159 -120.038718  506.0  506.0

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    3
# 1    1
# 2    0
# 3    5
# 4    0
# 5    2
# 6    0
# 7    6
# 8    5
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 0    3
# 1    2
# 5    2
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  0.984975  0.237728 -2.628110 -0.083077
# 1  1.487403  1.809151 -0.423099 -0.899411
# 2  0.598999  0.656849 -0.187914 -1.037914
# 3  0.675341  1.579861 -0.551315 -0.149807
# 4 -0.197917  0.177933 -0.361732 -0.737754
# 5  0.868250  0.370579  1.092059  1.357370
# 6  0.810432 -0.118000  0.459909  0.305591
# 7  0.166589  0.878796 -0.320346  0.247803
# 8  1.089734  0.942808 -0.385752 -1.169611
# 9 -0.022841  2.144844 -0.017189 -1.231033

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.984975  0.237728 -2.628110 -0.083077
# 1  1.487403  1.809151 -0.423099 -0.899411
# 2  0.598999  0.656849 -0.187914 -1.037914
# 3  0.675341  1.579861 -0.551315 -0.149807
# 4 -0.197917  0.177933 -0.361732 -0.737754
# 5  0.868250  0.370579  1.092059  1.357370
# 6  0.810432 -0.118000  0.459909  0.305591
# 7  0.166589  0.878796 -0.320346  0.247803
# 8  1.089734  0.942808 -0.385752 -1.169611
# 9 -0.022841  2.144844 -0.017189 -1.231033

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})
right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one -1.162440 -0.111148
# 1  bar    one  1.003586  0.954360
# 2  foo    two -0.439872  0.374956
# 3  bar  three -1.377241 -1.570811
# 4  foo    two -0.173950  0.347842
# 5  bar    two -1.690817  0.904314
# 6  foo    one  1.568994  0.952652
# 7  foo  three -0.527973  0.273530

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -2.064471  0.287863
# foo -0.735241  1.837831

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one    1.003586  0.954360
#     three -1.377241 -1.570811
#     two   -1.690817  0.904314
# foo one    0.406554  0.841504
#     three -0.527973  0.273530
#     two   -0.613822  0.722798

# %%
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]
index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.472294 -1.965896
#       two    -0.111707  0.730752
# baz   one    -0.672657 -0.046938
#       two     1.439091 -0.595699

# %%
stacked = df2.unstack().T
stacked
# Out:
# first          bar       baz
#   second
# A one     0.472294 -0.672657
#   two    -0.111707  1.439091
# B one    -1.965896 -0.046938
#   two     0.730752 -0.595699

# %%
stacked.unstack()
# Out:
# first        bar                 baz
# second       one       two       one       two
# A       0.472294 -0.111707 -0.672657  1.439091
# B      -1.965896  0.730752 -0.046938 -0.595699

# %%
stacked.unstack(1)
# Out:
# first        bar                 baz
# second       one       two       one       two
# A       0.472294 -0.111707 -0.672657  1.439091
# B      -1.965896  0.730752 -0.046938 -0.595699

# %%
stacked.unstack(0)
# Out:
# first        bar                 baz
#                A         B         A         B
# second
# one     0.472294 -1.965896 -0.672657 -0.046938
# two    -0.111707  0.730752  1.439091 -0.595699

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.591009 -0.584820
# 1     one  B  foo -1.753905  0.186252
# 2     two  C  foo  1.251279  0.372360
# 3   three  A  bar  0.060223  0.159728
# 4     one  B  bar -1.095377  0.451529
# 5     one  C  bar -1.157662 -0.045401
# 6     two  A  foo -1.188345  0.727709
# 7   three  B  foo  0.334884  0.727689
# 8     one  C  foo -0.204512  0.531101
# 9     one  A  bar  1.155997  0.552406
# 10    two  B  bar  0.819035 -1.171742
# 11  three  C  bar -0.301125 -0.261027

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  1.155997 -0.591009
#       B -1.095377 -1.753905
#       C -1.157662 -0.204512
# three A  0.060223       NaN
#       B       NaN  0.334884
#       C -0.301125       NaN
# two   A       NaN -1.188345
#       B  0.819035       NaN
#       C       NaN  1.251279

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2012-01-01    25806
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.291584
# 2012-03-07   -0.248190
# 2012-03-08    2.858269
# 2012-03-09   -0.694462
# 2012-03-10    0.242817
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.291584
# 2012-03-07 00:00:00+00:00   -0.248190
# 2012-03-08 00:00:00+00:00    2.858269
# 2012-03-09 00:00:00+00:00   -0.694462
# 2012-03-10 00:00:00+00:00    0.242817
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.291584
# 2012-03-06 19:00:00-05:00   -0.248190
# 2012-03-07 19:00:00-05:00    2.858269
# 2012-03-08 19:00:00-05:00   -0.694462
# 2012-03-09 19:00:00-05:00    0.242817
# Freq: D, dtype: float64

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df["grade"] = df["raw_grade"].astype("category")
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.close("all")

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df = df.cumsum()
plt.figure();
df.plot();
plt.legend(loc='best');

# %%
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  2  1  0  1  1
# 1           1  1  3  0  0  4
# 2           2  4  2  4  4  1
# 3           3  3  4  3  1  4
# 4           4  2  0  4  2  2
# 5           5  2  2  3  2  2
# 6           6  0  0  2  1  4
# 7           7  1  2  0  0  0
# 8           8  3  3  2  3  4
# 9           9  2  1  2  2  4

# %%
df.to_parquet("foo.parquet")
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  2  1  0  1  1
# 1  1  3  0  0  4
# 2  4  2  4  4  1
# 3  3  4  3  1  4
# 4  2  0  4  2  2
# 5  2  2  3  2  2
# 6  0  0  2  1  4
# 7  1  2  0  0  0
# 8  3  3  2  3  4
# 9  2  1  2  2  4

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  2  1  0  1  1
# 1           1  1  3  0  0  4
# 2           2  4  2  4  4  1
# 3           3  3  4  3  1  4
# 4           4  2  0  4  2  2
# 5           5  2  2  3  2  2
# 6           6  0  0  2  1  4
# 7           7  1  2  0  0  0
# 8           8  3  3  2  3  4
# 9           9  2  1  2  2  4

# %%
series = pd.Series([False, True, False])
if series.any():
    print("I was true")
# Out:
# I was true
